# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 25.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.16.0
#     Uninstalling pygit2-1.16.0:
#       Successfully uninstalled pygit2-1.16.0
# ...
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6722, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 6722 (delta 0), reused 0 (delta 0), pack-reused 6720 (from 2)
# Receiving objects: 100% (6722/6722), 33.26 MiB | 27.67 MiB/s, done.
# Resolving deltas: 100% (3876/3876), done.
# /content/Fooocus

# %%
# Download the model you want to run and save it to the checkpoint folder
# !wget -O /content/Fooocus/models/checkpoints/realism_engine_sdxl.safetensors https://civitai.com/api/download/models/258380?type=Model&format=SafeTensor&size=pruned&fp=fp16
# Out:
# --2025-01-17 13:54:09--  https://civitai.com/api/download/models/258380?type=Model
# Resolving civitai.com (civitai.com)... 104.22.19.237, 104.22.18.237, 172.67.12.143, ...
# Connecting to civitai.com (civitai.com)|104.22.19.237|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/8215/realismenginesdxlV20.ZghE.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22realismEngineSDXL_v20VAE.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250117/us-east-1/s3/aws4_request&X-Amz-Date=20250117T135409Z&X-Amz-SignedHeaders=host&X-Amz-Signature=7f1faf9843832295c69ed9ef1cd3d721db169d0e02d72776dd0d0d675cb641b2 [following]
# ...

# %%
# Download the model you want to run and save it to the checkpoint folder
# !wget -O /content/Fooocus/models/loras/eye_perfect.safetensors https://civitai.com/api/download/models/128461?type=Model&format=SafeTensor
# Out:
# --2025-01-17 14:34:14--  https://civitai.com/api/download/models/128461?type=Model
# Resolving civitai.com (civitai.com)... 104.22.19.237, 104.22.18.237, 172.67.12.143, ...
# Connecting to civitai.com (civitai.com)|104.22.19.237|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/224033/model/perfecteyesxl.5nPJ.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22PerfectEyesXL.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250117/us-east-1/s3/aws4_request&X-Amz-Date=20250117T143414Z&X-Amz-SignedHeaders=host&X-Amz-Signature=2c8044cde8a349f40aee6ac40acd02c50eeacabc57e4adfa76e57420e66a20e3 [following]
# ...

# %%
# Download the model you want to run and save it to the checkpoint folder
# !wget -O /content/Fooocus/models/loras/perfect_human.safetensors https://civitai.com/api/download/models/262705?type=Model&format=SafeTensor
# Out:
# --2025-01-17 14:52:09--  https://civitai.com/api/download/models/262705?type=Model
# Resolving civitai.com (civitai.com)... 104.22.19.237, 172.67.12.143, 104.22.18.237, ...
# Connecting to civitai.com (civitai.com)|104.22.19.237|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/12/realHumans.TKwP.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22real-humans-PublicPrompts.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250117/us-east-1/s3/aws4_request&X-Amz-Date=20250117T145211Z&X-Amz-SignedHeaders=host&X-Amz-Signature=73c6d4c3772f966ff0a986cbad64d423e0364df91e9f8d76034f871bdfb0c088 [following]
# ...

# %%
# !python entry_with_update.py --share --always-high-vram
# Out:
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0]
# Fooocus version: 2.5.5
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Total VRAM 15102 MB, total RAM 12979 MB
# Set vram state to: HIGH_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# Refiner unloaded.
# IMPORTANT: You are using gradio version 3.41.2, however version 4.44.1 is available, please upgrade.
# --------
# Running on local URL:  http://127.0.0.1:7865
# Running on public URL: https://d9ab1e339f175a456f.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# model_type EPS
# UNet ADM Dimension 2816
# Using pytorch attention in VAE
# ...
